# %%
import sys
# !{sys.executable} -m pip install -q -U pytesseract

# %%
import matplotlib.pyplot as plt
# text recognition
import cv2
import pytesseract
#import tesseract

# %%
# read image
path = r'C:\Users\carl\Documents\research\2024\ML\images\OCRExample.png'

image = cv2.imread(path)

# %%
plt.figure()
plt.title('image')
plt.imsave('1WTC.png', image, cmap='gray', format='png')
plt.imshow(image, cmap='gray')
plt.show()

# %%
# configurations
#config = ('-l eng --oem 1 --psm 3')

# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Apply threshold to convert to binary image
threshold_img = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# pytesseract
text = pytesseract.image_to_string(threshold_img)
# print text
#text = text.split('n')
print(text)
# Out:
# Explain
# that
# Stuff!
# 01234567490

# %%
#tesseract --version
print(pytesseract.__version__)
# Out:
# 0.3.10
